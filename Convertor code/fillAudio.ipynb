# %% [markdown]
# # __Fill up audiofile which not 2 sec__ 😮‍💨

# %%
import librosa
import soundfile as sf
from pydub import AudioSegment
import os

# %%
name = "Vanilla"
mode = "AI"

# %%
directory = "C:/Users/jeant/OneDrive - Chulalongkorn University/Desktop/Senior Project/Dataset/{} voice (16000)/{} 22500 trimmed/".format(mode,name)
# directory = "C:/Users/jeant/OneDrive - Chulalongkorn University/Desktop/Senior Project/Dataset/Wav voice (16000)/{} (trimmed)/".format(name)

desired_duration = 2000  # 2 seconds in milliseconds

for filename in os.listdir(directory):
    if filename.endswith(".wav"):
        full_path = os.path.join(directory, filename)

        sound = AudioSegment.from_file(full_path)

        print(f"Original duration of {filename}: {len(sound)} milliseconds")

        if len(sound) < desired_duration:
            duration_to_add = desired_duration - len(sound)

            silence = AudioSegment.silent(duration=duration_to_add)
            elongated_sound = sound + silence

            elongated_sound.export(full_path, format="wav")

            print(f"Elongated {filename} and saved in place")
        else:
            print(f"{filename} is already longer than 2 seconds.")
# Out:
# Original duration of Vanilla 1.wav: 1958 milliseconds
# Elongated Vanilla 1.wav and saved in place
# Original duration of Vanilla 10.wav: 1413 milliseconds
# Elongated Vanilla 10.wav and saved in place
# Original duration of Vanilla 11.wav: 1758 milliseconds
# Elongated Vanilla 11.wav and saved in place
# Original duration of Vanilla 12.wav: 1864 milliseconds
# Elongated Vanilla 12.wav and saved in place
# Original duration of Vanilla 13.wav: 1168 milliseconds
# Elongated Vanilla 13.wav and saved in place
# Original duration of Vanilla 14.wav: 1751 milliseconds
# Elongated Vanilla 14.wav and saved in place
# Original duration of Vanilla 15.wav: 1367 milliseconds
# Elongated Vanilla 15.wav and saved in place
# Original duration of Vanilla 16.wav: 1373 milliseconds
# Elongated Vanilla 16.wav and saved in place
# Original duration of Vanilla 17.wav: 1698 milliseconds
# Elongated Vanilla 17.wav and saved in place
# Original duration of Vanilla 18.wav: 1579 milliseconds
# ...

# %%
# file_path = "C:/Users/jeant/OneDrive - Chulalongkorn University/Desktop/Senior Project/Dataset/Wav voice (16000)/{} (trimmed)/".format(name)

file_path = "C:/Users/jeant/OneDrive - Chulalongkorn University/Desktop/Senior Project/Dataset/{} voice (16000)/{} 22500 trimmed/".format(mode,name)

for filename in os.listdir(directory):
    if filename.endswith(".wav"):
        file_path = os.path.join(directory, filename)
        try:
            y, sr = librosa.load(file_path)

            duration = librosa.get_duration(y=y, sr=sr)

            print(f"The duration of the audio file {filename} is: {duration:.2f} seconds")

        except Exception as e:
            print(f"Error processing {filename}: {e}")  # Catch potential errors
# Out:
# The duration of the audio file Vanilla 1.wav is: 2.00 seconds
# The duration of the audio file Vanilla 10.wav is: 2.00 seconds
# The duration of the audio file Vanilla 11.wav is: 2.00 seconds
# The duration of the audio file Vanilla 12.wav is: 2.00 seconds
# The duration of the audio file Vanilla 13.wav is: 2.00 seconds
# The duration of the audio file Vanilla 14.wav is: 2.00 seconds
# The duration of the audio file Vanilla 15.wav is: 2.00 seconds
# The duration of the audio file Vanilla 16.wav is: 2.00 seconds
# The duration of the audio file Vanilla 17.wav is: 2.00 seconds
# The duration of the audio file Vanilla 18.wav is: 2.00 seconds
# The duration of the audio file Vanilla 19.wav is: 2.00 seconds
# The duration of the audio file Vanilla 2.wav is: 2.00 seconds
# The duration of the audio file Vanilla 20.wav is: 2.00 seconds
# The duration of the audio file Vanilla 21.wav is: 2.00 seconds
# The duration of the audio file Vanilla 22.wav is: 2.00 seconds
# ...

# %%
# directory = "C:/Users/jeant/OneDrive - Chulalongkorn University/Desktop/Senior Project/Dataset/Wav voice (16000)/Mai.wav (trimmed)/"
# output_dir = "C:/Users/jeant/OneDrive - Chulalongkorn University/Desktop/Senior Project/Dataset/Wav voice (16000)/Mai.wav (trimmed) - test/"

# desired_duration = 2000  # 2 seconds in milliseconds

# for filename in os.listdir(directory):
#     if filename.endswith(".wav"):
#         full_path = os.path.join(directory, filename)

#         # Load the audio file
#         sound = AudioSegment.from_file(full_path)

#         # Print the original duration for verification (optional)
#         print(f"Original duration of {filename}: {len(sound)} milliseconds")

#         # Check if the audio is shorter than desired_duration
#         if len(sound) < desired_duration:
#             # Calculate the duration to add
#             duration_to_add = desired_duration - len(sound)

#             # Add silence to elongate the audio
#             silence = AudioSegment.silent(duration=duration_to_add)
#             elongated_sound = sound + silence

#             # Generate a new filename for the elongated audio
#             output_filename = f"elongated_{filename}"  # Avoid overwriting original files
#             output_path = os.path.join(output_dir, output_filename)

#             # Export the elongated audio with a specific format (e.g., WAV)
#             elongated_sound.export(output_path, format="wav")

#             print(f"Elongated {filename} and saved as {output_filename}")
#         else:
#             print(f"{filename} is already longer than 2 seconds.")
